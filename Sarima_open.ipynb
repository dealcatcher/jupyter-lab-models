# %% [markdown]
# # OPEN PRICES
#  - Here we all use the open prices dataset.
#  - we will use sorting, indexing , and loading data then , we will use the discount cycles ,season pattern m trend , and more

# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv("./open_prices.csv", encoding='latin1')


df.head()
# Out:
# /var/folders/st/r78_rxtx0hd_yr_r8qtl08_c0000gn/T/ipykernel_40980/4037195694.py:5: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./open_prices.csv", encoding='latin1')
#       id     type     product_code product_name category_tag labels_tags  \
# 0  42629  PRODUCT  3560070283484.0          NaN          NaN         NaN
# 1  42630  PRODUCT  3560070206469.0          NaN          NaN         NaN
# 2  39637  PRODUCT  3123930711758.0          NaN          NaN         NaN
# 3  39573  PRODUCT  3500390010247.0          NaN          NaN         NaN
# 4  33784  PRODUCT  8033976484743.0          NaN          NaN         NaN
#
#   origins_tags  price  price_is_discounted  price_without_discount  ...  \
# 0          NaN   1.25                False                     NaN  ...
# 1          NaN   1.99                False                     NaN  ...
# 2          NaN   3.60                False                     NaN  ...
# ...

# %% [markdown]
# ### Selecting & Filtering Data
# - we will remove the data that we do not need

# %%
cols = [
    "category_tag", "labels_tag", "origin_tag",
    "location_osm_id", "location_id",
    "proof_id", "receipt_quantity", "owner",
    "proof_file_path", "proof_mimetype", "proof_currency",
    "proof_receipt_price_count", "proof_receipt_price_total",
    "proof_owner", "proof_source",
    "proof_created", "proof_updated",
    "location_osm_address_country_code",
    "location_osm_lat", "location_osm_lon",
    "location_name", "location_address", "location_city",
    "location_postcode", "location_state",
    "location_country_code", "location_lat", "location_lon",
    "location_tags", "location_source",
    "location_owner", "location_created", "location_updated",
    "location_website_url"
]

df = df.drop(columns=cols, )
df.head()
# Out:
#       id     type     product_code product_name labels_tags origins_tags  \
# 0  42629  PRODUCT  3560070283484.0          NaN         NaN          NaN
# 1  42630  PRODUCT  3560070206469.0          NaN         NaN          NaN
# 2  39637  PRODUCT  3123930711758.0          NaN         NaN          NaN
# 3  39573  PRODUCT  3500390010247.0          NaN         NaN          NaN
# 4  33784  PRODUCT  8033976484743.0          NaN         NaN          NaN
#
#    price  price_is_discounted  price_without_discount discount_type  ...  \
# 0   1.25                False                     NaN           NaN  ...
# 1   1.99                False                     NaN           NaN  ...
# 2   3.60                False                     NaN           NaN  ...
# 3  19.95                False                     NaN           NaN  ...
# 4   2.99                False                     NaN           NaN  ...
#
#                             updated proof_type  proof_date location_type  \
# ...
