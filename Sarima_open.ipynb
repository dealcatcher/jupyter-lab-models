# %% [markdown]
# # OPEN PRICES
#  - Here we all use the open prices dataset.
#  - we will use sorting, indexing , and loading data then , we will use the discount cycles ,season pattern m trend , and more

# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv("./open_prices.csv", encoding='latin1')


df.info()
# Out:
# /var/folders/st/r78_rxtx0hd_yr_r8qtl08_c0000gn/T/ipykernel_9756/2012436382.py:5: DtypeWarning: Columns (0: product_code) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./open_prices.csv", encoding='latin1')
# <class 'pandas.DataFrame'>
# RangeIndex: 178113 entries, 0 to 178112
# Data columns (total 48 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   id                                 178113 non-null  int64
#  1   type                               178113 non-null  str
#  2   product_code                       170911 non-null  object
#  3   product_name                       100923 non-null  str
#  4   category_tag                       7202 non-null    str
#  5   labels_tags                        4308 non-null    str
#  6   origins_tags                       6912 non-null    str
#  7   price                              178113 non-null  float64
#  8   price_is_discounted                178113 non-null  bool
#  9   price_without_discount             12796 non-null   float64
#  10  discount_type                      8920 non-null    str
#  11  price_per                          7202 non-null    str
#  12  currency                           177942 non-null  str
#  13  location_osm_id                    177638 non-null  float64
#  14  location_osm_type                  177638 non-null  str
#  15  location_id                        178113 non-null  int64
#  16  date                               177927 non-null  str
#  17  proof_id                           177984 non-null  float64
#  18  receipt_quantity                   51077 non-null   float64
#  19  owner                              178113 non-null  str
#  20  source                             161308 non-null  str
#  21  created                            178113 non-null  str
#  22  updated                            178113 non-null  str
#  23  proof_file_path                    177984 non-null  str
#  24  proof_mimetype                     177984 non-null  str
#  25  proof_type                         177984 non-null  str
#  26  proof_date                         156056 non-null  str
#  27  proof_currency                     163669 non-null  str
#  28  proof_receipt_price_count          10783 non-null   float64
#  29  proof_receipt_price_total          10450 non-null   float64
#  30  proof_owner                        177984 non-null  str
#  31  proof_source                       161185 non-null  str
#  32  proof_created                      177984 non-null  str
#  33  proof_updated                      177984 non-null  str
#  34  location_type                      178113 non-null  str
#  35  location_osm_display_name          177604 non-null  str
#  36  location_osm_tag_key               177399 non-null  str
#  37  location_osm_tag_value             177399 non-null  str
#  38  location_osm_address_postcode      174612 non-null  str
#  39  location_osm_address_city          174753 non-null  str
#  40  location_osm_address_country       177604 non-null  str
#  41  location_osm_address_country_code  177399 non-null  str
#  42  location_osm_lat                   177604 non-null  float64
#  43  location_osm_lon                   177604 non-null  float64
#  44  location_website_url               475 non-null     str
#  45  location_source                    648 non-null     str
#  46  location_created                   178113 non-null  str
#  47  location_updated                   178113 non-null  str
# dtypes: bool(1), float64(9), int64(2), object(1), str(35)
# memory usage: 157.4+ MB

# %%
df = df.dropna(subset=[''])
